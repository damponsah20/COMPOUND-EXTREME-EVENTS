# %%
import xarray as xr
import matplotlib.pyplot as plt

# %%
Tx = xr.open_dataset('Ghana_ERA5_dTx_1960_2024.nc')
Tn = xr.open_dataset('Ghana_ERA5_dTn_1960_2024.nc')
# Out:
# C:\Users\ampon\anaconda3\lib\site-packages\xarray\coding\times.py:724: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   dtype = _decode_cf_datetime_dtype(data, units, calendar, self.use_cftime)
# C:\Users\ampon\anaconda3\lib\site-packages\xarray\coding\times.py:210: CFWarning: this date/calendar/year zero convention is not supported by CF
#   cftime.num2date(num_dates, units, calendar, only_use_cftime_datetimes=True)
# C:\Users\ampon\anaconda3\lib\site-packages\xarray\core\indexing.py:557: SerializationWarning: Unable to decode time axis into full numpy.datetime64 objects, continuing using cftime.datetime objects instead, reason: dates out of range
#   array = array.get_duck_array()

# %%
Tx
# Out:
# C:\Users\ampon\anaconda3\lib\site-packages\xarray\core\resample_cftime.py:495: CFWarning: this date/calendar/year zero convention is not supported by CF
#   seconds = b.replace(microsecond=0) - a.replace(microsecond=0)
# <xarray.Dataset>
# Dimensions:    (time: 23742, longitude: 21, latitude: 31)
# Coordinates:
#   * time       (time) object 1960-01-01 15:00:00 ... 168429-04-16 22:00:00
#   * longitude  (longitude) float64 -3.5 -3.25 -3.0 -2.75 ... 0.75 1.0 1.25 1.5
#   * latitude   (latitude) float64 12.0 11.75 11.5 11.25 ... 5.25 5.0 4.75 4.5
# Data variables:
#     mx2t       (time, latitude, longitude) float64 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.9.9rc1 (https://mpimet.mpg...
#     Conventions:  CF-1.6
#     history:      Mon Jun 30 13:20:06 2025: cdo mergetime tta.nc Ghana_ERA5_d...
#     CDO:          Climate Data Operators version 1.9.9rc1 (https://mpimet.mpg...

# %%
Tn
# Out:
# <xarray.Dataset>
# Dimensions:    (time: 23741, longitude: 21, latitude: 31)
# Coordinates:
#   * time       (time) datetime64[ns] 1960-01-01T06:00:00 ... 2024-12-31T11:00:00
#   * longitude  (longitude) float64 -3.5 -3.25 -3.0 -2.75 ... 0.75 1.0 1.25 1.5
#   * latitude   (latitude) float64 12.0 11.75 11.5 11.25 ... 5.25 5.0 4.75 4.5
# Data variables:
#     mn2t       (time, latitude, longitude) float64 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.9.9rc1 (https://mpimet.mpg...
#     Conventions:  CF-1.6
#     history:      Mon Jun 30 13:17:47 2025: cdo mergetime tta.nc Ghana_ERA5_d...
#     CDO:          Climate Data Operators version 1.9.9rc1 (https://mpimet.mpg...
